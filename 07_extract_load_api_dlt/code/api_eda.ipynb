# %%
import requests
import json

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")



query = 'lärare uppsala'
example_search_loop_through_hits(query)
# Out:
# Lärare till Uppsala, Glaveby Consulting AB
# JENSEN gymnasium Uppsala söker lärare i matematik/engelska, Jensen Education AB
# Lärare i SVA/SFI till utbildnings- och jobbcenter i Uppsala, Uppsala kommun
# Lärare i SVA/SFI till Utbildnings- och jobbcenter i Uppsala (kvällstid), Uppsala kommun
# Lärare luftbevakning Utbildningsavdelningen StrilS, Försvarsmakten
# Lärare årskurs F-3 till Flogstaskolan, Uppsala kommun
# Lärarvikarier i samtliga ämneskombinationer till Grillska gymnasiet i Uppsa, Stadsmissionens Skolstift
# Yrkeslärare barn och fritid till Ellen Fries gymnasium, Uppsala kommun
# Lärare åk 3-5 till Danmarks skola, Uppsala kommun
# Förskollärare och lärare till olika skolformer, Clockwork Bemanning & Rekrytering AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB

# %%
example_search_return_number_of_hits(query)

# %%
search_params = {'q': query, 'limit': 100}
json_response = _get_ads(search_params)
#json_response
# Out:
# {'total': {'value': 11},
#  'positions': 21,
#  'query_time_in_millis': 5,
#  'result_time_in_millis': 163,
#  'stats': [],
#  'freetext_concepts': {'skill': [],
#   'occupation': ['lärare'],
#   'location': ['uppsala'],
#   'skill_must': [],
#   'occupation_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'location_must_not': []},
#  'hits': [{'relevance': 1.0,
#    'id': '29954986',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29954986',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/arbetsplatser/86660456/logotyper/logo.png',
#    'headline': 'Lärare till Uppsala',
#    'application_deadline': '2025-09-26T23:59:59',
#    'number_of_vacancies': 2,
#    'description': {'text': 'Vi söker nu lärare som vill vikariera på skolor. Vi söker främst lärare för åk 4-6 samt 7-9.\nVi på Vikarielärare hjälper skolor att kvalitetssäkra undervisningen när ordinarie personal inte har möjlighet. Vikarielärare finns till för att alltid bedriva viktig och meningsfull undervisning som håller samma höga kvalitet som ordinarie lärares.\nVi förmedlar lärare som kommer in och vikarierar och hjälper till när skolans egna pedagoger inte är där. Vi erbjuder undervisning, lektionsplanering, lpp-utformning, provrättning och annat som skolan kan behöva hjälp med av en legitimerad lärare med mycket goda referenser. Vikarielärare får tack vare sin unika profil in stora mängder förfrågningar från skolor.\nVikarielärare söker lärare inom alla ämnen och årskurser. Vikarielärare tar sig an såväl längre som kortare vikariat där allt mellan planering, bedömning, undervisning och betygsättning kan ingå.\nVi jobbar även med rekryteringar åt våra skolor. Är du behörig lärare så finns det chans att få ett nytt fast jobb genom oss direkt på en skola.\nUppdragen riktar sig bland annat till dig som;\nbrinner för undervisning men inte vill ha ansvaret för en klass/ämne,\nfunderar på att bli lärare eller studerar till lärare och vill samla på dig mer erfarenhet,\när pensionär,\npå väg tillbaka från ett arbetsuppehåll.',
#     'text_formatted': '<p>Vi söker nu lärare som vill vikariera på skolor. Vi söker främst lärare för åk 4-6 samt 7-9.</p><p>Vi på Vikarielärare hjälper skolor att kvalitetssäkra undervisningen när ordinarie personal inte har möjlighet. Vikarielärare finns till för att alltid bedriva viktig och meningsfull undervisning som håller samma höga kvalitet som ordinarie lärares.</p><p>Vi förmedlar lärare som kommer in och vikarierar och hjälper till när skolans egna pedagoger inte är där. Vi erbjuder undervisning, lektionsplanering, lpp-utformning, provrättning och annat som skolan kan behöva hjälp med av en legitimerad lärare med mycket goda referenser. Vikarielärare får tack vare sin unika profil in stora mängder förfrågningar från skolor.</p><p>Vikarielärare söker lärare inom alla ämnen och årskurser. Vikarielärare tar sig an såväl längre som kortare vikariat där allt mellan planering, bedömning, undervisning och betygsättning kan ingå.</p><p>Vi jobbar även med rekryteringar åt våra skolor. Är du behörig lärare så finns det chans att få ett nytt fast jobb genom oss direkt på en skola.</p><p>Uppdragen riktar sig bland annat till dig som;</p><ul><li>brinner för undervisning men inte vill ha ansvaret för en klass/ämne,</li><li>funderar på att bli lärare eller studerar till lärare och vill samla på dig mer erfarenhet,</li><li>är pensionär,</li><li>på väg tillbaka från ett arbetsuppehåll.</li></ul>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': '1paU_aCR_nGn',
#     'label': 'Behovsanställning',
#     'legacy_ams_taxonomy_id': '4'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'working_hours_type': {'concept_id': None,
#     'label': None,
#     'legacy_ams_taxonomy_id': None},
#    'scope_of_work': {'min': None, 'max': None},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'http://www.vikarielarare.se',
#     'organization_number': '5569878878',
#     'name': 'Glaveby Consulting AB',
#     'workplace': 'Vikarielärare Uppsala'},
#    'application_details': {'information': None,
#     'reference': 'Uppsala',
#     'email': 'ansokan@vikarielarare.se',
#     'via_af': False,
#     'url': None,
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'Nzmh_iTb_z7h',
#     'label': 'Grundlärare, 4-6',
#     'legacy_ams_taxonomy_id': '7653'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]},
#    'must_have': {'skills': [],
#     'languages': [{'weight': 10,
#       'concept_id': 'zSLA_vw2_FXN',
#       'label': 'Svenska',
#       'legacy_ams_taxonomy_id': '502'}],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [{'weight': 5,
#       'concept_id': 'zJZd_pDs_SDf',
#       'label': 'Lärarexamen',
#       'legacy_ams_taxonomy_id': '608391'},
#      {'weight': 5,
#       'concept_id': 'Tp1G_2jt_rN4',
#       'label': 'Lärarexamen inr senare år',
#       'legacy_ams_taxonomy_id': '608074'}],
#     'languages': [],
#     'work_experiences': [{'weight': 5,
#       'concept_id': 'Nzmh_iTb_z7h',
#       'label': 'Grundlärare, 4-6',
#       'legacy_ams_taxonomy_id': '7653'}],
#     'education': [{'weight': 5,
#       'concept_id': 'tFCz_HSa_jwW',
#       'label': 'Pedagogik och lärarutbildning',
#       'legacy_ams_taxonomy_id': '4'}],
#     'education_level': [{'weight': 5,
#       'concept_id': 'asZm_TEQ_Srk',
#       'label': 'Eftergymnasial utbildning två år eller längre',
#       'legacy_ams_taxonomy_id': '6'}]},
#    'application_contacts': [],
#    'publication_date': '2025-08-27T11:04:00',
#    'last_publication_date': '2025-09-26T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1756285440668},
#   {'relevance': 0.8738360846531942,
#    'id': '29945956',
#    'external_id': '46-556532-7201-4568',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29945956',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/5565327201/logotyper/logo.png',
#    'headline': 'JENSEN gymnasium Uppsala söker lärare i matematik/engelska',
#    'application_deadline': '2025-09-07T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'JENSEN gymnasium Uppsala startade 2008\xa0i centrala Uppsala. Vi är en av Uppsalas största skolor och ligger mitt i centrum, perfekt för dig som pendlar. Med närmare två decennier i väggarna erbjuder vi både nytänkande och traditioner. Vi är ett starkt team där var och en tar ansvar för att bygga den fantastiska skola som är JENSEN gymnasium Uppsala.\n\nNu söker vi en engagerad och legitimerad lärare i matematik och engelska. Om du är behörig i ett av ämnena kan det också bli aktuellt.\n\n\n\nTräning för verkligheten och bildning är målet,\xa0är den röda tråden i hur vi utbildar våra elever. Vi har fokus på litteratur, läsande och skrivande för att bygga en stadig grund för högre studier. Som lärare i matematik och engelska ingår du i två ämneslag som tillsammans utvecklar undervisningen för att aktivera eleverna och ebgagera dem i lektionerna. Vi jobbar för att våra elever ska nå en hög kunskapsnivå och utveckla sitt tänkande - att tänka fritt och tänka stort - det är bildning för oss! På JENSEN gymnasium håller vi hög kvalitet, vilket bekräftas i Skolinspektionens kvalitetsgranskningar.\n\nVår företagskultur präglas av höga ambitioner, professionalitet, hälsoprofil och även en uttalad dresscode. Vi har en positiv teamkänsla där alla medarbetare bidrar i att ta ansvar för helheten. På vår senaste nationella medarbetarenkät rekommenderar hela 92% JENSEN som arbetsplats, mycket på grund av arbetsmiljön!\xa0Eftersom vi har en tydlig hälsoprofil är du troligtvis inne på samma spår.\n\nKvalifikationer\nVi söker dig som är behörig gymnasielärare i matematik och engelska. Som person har du, precis som vi, ett stort engagemang för att utvecklas tillsammans med andra. Du trivs med att arbeta teaminriktat. Du är strukturerad, drivande och gillar att vara en tydlig ledare i klassrummet. Du planerar dina lektioner så att eleverna motiveras att vara aktiva. Du är väl införstådd i gällande styrdokument.\n\nAnställningsform\nTjänsten är en tillsvidareanställning på 100%, med omgående start.\xa0För den här tjänsten tillämpar vi ferietjänst och sex månader provanställning.\n\nDin ansökan\nDu ansöker genom att registrera din profil och bifoga ett personligt brev och CV i vårt rekryteringssystem. Vi tar enbart emot ansökningar via webben, ansökningar som kommer in på annat sätt kan tyvärr ej behandlas. Urval sker löpande, därför vill vi gärna ha din ansökan så snart som möjligt.\xa0\n\nInom gymnasieskolan måste du enligt lag (2000:873) visa upp ett utdrag från belastningsregistret. Utdraget görs via polisen.se med digitalt BankID. Om du inte har BankID, så kan du beställa hem blanketten, gör detta så snart som möjligt då manuell hantering av blanketten tar lång tid.\xa0\xa0\n\nFörsta steget i vår rekryteringsprocess är att genomföra två arbetspsykologiska tester. Efter inskickad ansökan får du två mejl direkt efter varandra med testlänkar. Återkoppling får du direkt efter genomförda tester. Har du inte fått något mejl med länk till tester, vänligen kolla i din skräppost då mejlet kan hamna där.\n\nKontaktuppgifter\nVill du veta mer om tjänsten och hur det är att jobba hos oss, vänligen kontakta rektor Lisa Helin på lisa.helin@jenseneducation.se.\n\nVill du veta mer om hur det är att jobba på JENSEN gymnasium? Läs mer här!\n\nVarmt välkommen med din ansökan!',
#     'text_formatted': 'JENSEN gymnasium Uppsala startade 2008\xa0i centrala Uppsala. Vi är en av Uppsalas största skolor och ligger mitt i centrum, perfekt för dig som pendlar. Med närmare två decennier i väggarna erbjuder vi både nytänkande och traditioner. Vi är ett starkt team där var och en tar ansvar för att bygga den fantastiska skola som är JENSEN gymnasium Uppsala.\n\nNu söker vi en engagerad och legitimerad lärare i matematik och engelska. Om du är behörig i ett av ämnena kan det också bli aktuellt.\n\n\n\nTräning för verkligheten och bildning är målet,\xa0är den röda tråden i hur vi utbildar våra elever. Vi har fokus på litteratur, läsande och skrivande för att bygga en stadig grund för högre studier. Som lärare i matematik och engelska ingår du i två ämneslag som tillsammans utvecklar undervisningen för att aktivera eleverna och ebgagera dem i lektionerna. Vi jobbar för att våra elever ska nå en hög kunskapsnivå och utveckla sitt tänkande - att tänka fritt och tänka stort - det är bildning för oss! På JENSEN gymnasium håller vi hög kvalitet, vilket bekräftas i Skolinspektionens kvalitetsgranskningar.\n\nVår företagskultur präglas av höga ambitioner, professionalitet, hälsoprofil och även en uttalad dresscode. Vi har en positiv teamkänsla där alla medarbetare bidrar i att ta ansvar för helheten. På vår senaste nationella medarbetarenkät rekommenderar hela 92% JENSEN som arbetsplats, mycket på grund av arbetsmiljön!\xa0Eftersom vi har en tydlig hälsoprofil är du troligtvis inne på samma spår.\n\nKvalifikationer\nVi söker dig som är behörig gymnasielärare i matematik och engelska. Som person har du, precis som vi, ett stort engagemang för att utvecklas tillsammans med andra. Du trivs med att arbeta teaminriktat. Du är strukturerad, drivande och gillar att vara en tydlig ledare i klassrummet. Du planerar dina lektioner så att eleverna motiveras att vara aktiva. Du är väl införstådd i gällande styrdokument.\n\nAnställningsform\nTjänsten är en tillsvidareanställning på 100%, med omgående start.\xa0För den här tjänsten tillämpar vi ferietjänst och sex månader provanställning.\n\nDin ansökan\nDu ansöker genom att registrera din profil och bifoga ett personligt brev och CV i vårt rekryteringssystem. Vi tar enbart emot ansökningar via webben, ansökningar som kommer in på annat sätt kan tyvärr ej behandlas. Urval sker löpande, därför vill vi gärna ha din ansökan så snart som möjligt.\xa0\n\nInom gymnasieskolan måste du enligt lag (2000:873) visa upp ett utdrag från belastningsregistret. Utdraget görs via polisen.se med digitalt BankID. Om du inte har BankID, så kan du beställa hem blanketten, gör detta så snart som möjligt då manuell hantering av blanketten tar lång tid.\xa0\xa0\n\nFörsta steget i vår rekryteringsprocess är att genomföra två arbetspsykologiska tester. Efter inskickad ansökan får du två mejl direkt efter varandra med testlänkar. Återkoppling får du direkt efter genomförda tester. Har du inte fått något mejl med länk till tester, vänligen kolla i din skräppost då mejlet kan hamna där.\n\nKontaktuppgifter\nVill du veta mer om tjänsten och hur det är att jobba hos oss, vänligen kontakta rektor Lisa Helin på lisa.helin@jenseneducation.se.\n\nVill du veta mer om hur det är att jobba på JENSEN gymnasium? Läs mer här!\n\nVarmt välkommen med din ansökan!',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid/\r\nEj specificerat'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Individuell lönesättning',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'http://www.jenseneducation.se/',
#     'organization_number': '5565327201',
#     'name': 'Jensen Education AB',
#     'workplace': 'JENSEN education'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://jobb.jenseneducation.se/job-details.html?rmpage=apply&rmjob=4568&ref=arbetsformedlingen.se%2Fplatsbanken%2F&utm_medium=talentech_publishing&utm_source=platsbanken',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'f8q7_Rwv_TP4',
#     'label': 'Lärare i gymnasieskolan',
#     'legacy_ams_taxonomy_id': '7127'},
#    'occupation_group': {'concept_id': '4KhP_FxL_uZ5',
#     'label': 'Gymnasielärare',
#     'legacy_ams_taxonomy_id': '2330'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [17.638927, 59.858562]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'f8q7_Rwv_TP4',
#       'label': 'Lärare i gymnasieskolan',
#       'legacy_ams_taxonomy_id': '7127'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-08-25T13:53:05',
#    'last_publication_date': '2025-09-07T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1756122785701},
#   {'relevance': 0.8345946755629406,
#    'id': '29945806',
#    'external_id': '46-212000-3005-1CD3BB5D8BF347259D3A1B6ED306E59E',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29945806',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2120003005/logotyper/logo.png',
#    'headline': 'Lärare i SVA/SFI till utbildnings- och jobbcenter i Uppsala',
#    'application_deadline': '2025-09-07T23:59:59',
#    'number_of_vacancies': 4,
#    'description': {'text': 'Välkommen till arbetsmarknadsförvaltningen. Här arbetar vi med arbetsmarknadsinsatser, försörjningsstöd, vuxenutbildning, konsumentfrågor och introduktion av nyanlända. Målet är att alla ska erbjudas möjlighet till egen försörjning. Därför arbetar vi nära näringslivet och arbetslivets parter för att öka möjligheten för personer att etablera sig på arbetsmarknaden.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nÄr du lärare i svenska som andraspråk och vill vara med och ge vuxna möjligheten att studera?\xa0 Gillar du att uppmuntra elevernas kunskapsbyggande och utforskande? Då kan det här vara jobbet för dig!\n\n\nUtbildnings- och jobbcenter i Uppsala är en kommunal vuxenutbildning belägen på flera adresser i Uppsala. Vi erbjuder vuxna möjligheten att studera svenska för invandrare (SFI), allmänna ämnen på grundläggande och gymnasial nivå, yrkesutbildningar samt komvux som anpassad utbildning.\n\n\nVåra kurser bedrivs i form av närundervisning och flexibla former. Utbildnings- och jobbcenter driver också ett lärcentrum i Gottsunda.\n\n\nVi arbetar aktivt med att integrera digital teknik i undervisningen. Alla lärare har tillgång till egen laptop och skolan är välutrustad med smartboards i alla klassrum. Vårt lärarlag präglas av flexibilitet och samarbete och pedagogiska diskussioner.\n\n\nGenom den här annonsen söker vi flera lärare till klassrumsundervisning för undervisning dagtid och kvällstid.\n\n\nBeskrivning av arbetsuppgifter\n\n\nSom lärare i svenska som andraspråk kommer du att planera, genomföra och följa upp undervisningen. Du förväntas uppmuntra elevernas kunskapsbyggande och utforskande samt bedriva en anpassad pedagogisk verksamhet utifrån både individens och gruppens behov och förutsättningar. Undervisningen bedrivs med hjälp av datorer och andra digitala hjälpmedel. Det ingår även att bidra till att utveckla skolans lärmiljö tillsammans med elever och övrig personal.\n\n\nKvalifikationer\n\n\nVi söker dig som har svensk lärarlegitimation med behörighet att undervisa i svenska som andraspråk. För att lyckas i arbetet behöver du ha it-kunskaper med inriktning mot pedagogiskt arbete och god kännedom om skolans styrdokument och läroplan. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska. Har du erfarenhet av undervisning för vuxna ses det som meriterande.\n\n\nSom person är du pedagogisk och har förståelse för människors olika förutsättningar att ta till sig kunskap. Du är utåtriktad och socialt aktiv i yrkesmässiga sammanhang. Jobbet passar dig som samarbetar och relaterar till andra på ett lyhört och smidigt sätt.\n\n\nUpplysningar\n\n\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Sabah Göransson, biträdande rektor, 018-727 44 99.\n\n\nFacklig företrädare: Sveriges lärare, Heidi Bischof, 018-727 24 51.\n\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24.\n\n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\n\n\nEn anställning hos Uppsala kommun kan komma att innebära en krigsplacering.',
#     'text_formatted': 'Välkommen till arbetsmarknadsförvaltningen. Här arbetar vi med arbetsmarknadsinsatser, försörjningsstöd, vuxenutbildning, konsumentfrågor och introduktion av nyanlända. Målet är att alla ska erbjudas möjlighet till egen försörjning. Därför arbetar vi nära näringslivet och arbetslivets parter för att öka möjligheten för personer att etablera sig på arbetsmarknaden.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nÄr du lärare i svenska som andraspråk och vill vara med och ge vuxna möjligheten att studera?\xa0 Gillar du att uppmuntra elevernas kunskapsbyggande och utforskande? Då kan det här vara jobbet för dig!\n\n\nUtbildnings- och jobbcenter i Uppsala är en kommunal vuxenutbildning belägen på flera adresser i Uppsala. Vi erbjuder vuxna möjligheten att studera svenska för invandrare (SFI), allmänna ämnen på grundläggande och gymnasial nivå, yrkesutbildningar samt komvux som anpassad utbildning.\n\n\nVåra kurser bedrivs i form av närundervisning och flexibla former. Utbildnings- och jobbcenter driver också ett lärcentrum i Gottsunda.\n\n\nVi arbetar aktivt med att integrera digital teknik i undervisningen. Alla lärare har tillgång till egen laptop och skolan är välutrustad med smartboards i alla klassrum. Vårt lärarlag präglas av flexibilitet och samarbete och pedagogiska diskussioner.\n\n\nGenom den här annonsen söker vi flera lärare till klassrumsundervisning för undervisning dagtid och kvällstid.\n\n\nBeskrivning av arbetsuppgifter\n\n\nSom lärare i svenska som andraspråk kommer du att planera, genomföra och följa upp undervisningen. Du förväntas uppmuntra elevernas kunskapsbyggande och utforskande samt bedriva en anpassad pedagogisk verksamhet utifrån både individens och gruppens behov och förutsättningar. Undervisningen bedrivs med hjälp av datorer och andra digitala hjälpmedel. Det ingår även att bidra till att utveckla skolans lärmiljö tillsammans med elever och övrig personal.\n\n\nKvalifikationer\n\n\nVi söker dig som har svensk lärarlegitimation med behörighet att undervisa i svenska som andraspråk. För att lyckas i arbetet behöver du ha it-kunskaper med inriktning mot pedagogiskt arbete och god kännedom om skolans styrdokument och läroplan. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska. Har du erfarenhet av undervisning för vuxna ses det som meriterande.\n\n\nSom person är du pedagogisk och har förståelse för människors olika förutsättningar att ta till sig kunskap. Du är utåtriktad och socialt aktiv i yrkesmässiga sammanhang. Jobbet passar dig som samarbetar och relaterar till andra på ett lyhört och smidigt sätt.\n\n\nUpplysningar\n\n\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Sabah Göransson, biträdande rektor, 018-727 44 99.\n\n\nFacklig företrädare: Sveriges lärare, Heidi Bischof, 018-727 24 51.\n\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24.\n\n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\n\n\nEn anställning hos Uppsala kommun kan komma att innebära en krigsplacering. \xa0',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid. \r\nTillsvidareanställning, tillträde: Enligt överenskommelse.'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Månadslön',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2120003005',
#     'name': 'Uppsala kommun',
#     'workplace': 'Uppsala kommun, Vuxenutbildning'},
#    'application_details': {'information': None,
#     'reference': 'AMN-2025-00529',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=1cd3bb5d-8bf3-4725-9d3a-1b6ed306e59e&publishCode=AMS&TK=8a5669c7-4a54-44f6-90d0-dd9bbf231a32',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '15e8_KDZ_31Z',
#     'label': 'SFI-lärare',
#     'legacy_ams_taxonomy_id': '7382'},
#    'occupation_group': {'concept_id': 'mcRJ_kq2_jFr',
#     'label': 'Övriga pedagoger med teoretisk specialistkompetens',
#     'legacy_ams_taxonomy_id': '2359'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [17.638927, 59.858562]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Sabah Göransson',
#      'email': None,
#      'telephone': '018-727 44 99',
#      'contact_type': 'Biträdande rektor'}],
#    'publication_date': '2025-08-25T13:40:37',
#    'last_publication_date': '2025-09-07T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1756122037016},
#   {'relevance': 0.8184619601857737,
#    'id': '29945802',
#    'external_id': '46-212000-3005-4D54633AC0B34FBD997D9FB8B9619C59',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29945802',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2120003005/logotyper/logo.png',
#    'headline': 'Lärare i SVA/SFI till Utbildnings- och jobbcenter i Uppsala (kvällstid)',
#    'application_deadline': '2025-09-07T23:59:59',
#    'number_of_vacancies': 3,
#    'description': {'text': 'Välkommen till arbetsmarknadsförvaltningen. Här arbetar vi med arbetsmarknadsinsatser, försörjningsstöd, vuxenutbildning, konsumentfrågor och introduktion av nyanlända. Målet är att alla ska erbjudas möjlighet till egen försörjning. Därför arbetar vi nära näringslivet och arbetslivets parter för att öka möjligheten för personer att etablera sig på arbetsmarknaden.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nÄr du lärare i svenska som andraspråk och vill vara med och ge vuxna möjligheten att studera?\xa0 Gillar du att uppmuntra elevernas kunskapsbyggande och utforskande? Då kan det här vara jobbet för dig!\n\n\nUtbildnings- och jobbcenter i Uppsala är en kommunal vuxenutbildning belägen på flera adresser i Uppsala. Vi erbjuder vuxna möjligheten att studera svenska för invandrare (SFI), allmänna ämnen på grundläggande och gymnasial nivå, yrkesutbildningar samt komvux som anpassad utbildning.\n\n\nVåra kurser bedrivs i form av närundervisning och flexibla former. Utbildnings- och jobbcenter driver också ett lärcentrum i Gottsunda.\n\n\nVi arbetar aktivt med att integrera digital teknik i undervisningen. Alla lärare har tillgång till egen laptop och skolan är välutrustad med smartboards i alla klassrum. Vårt lärarlag präglas av flexibilitet och samarbete och pedagogiska diskussioner.\n\n\nGenom den här annonsen söker vi flera lärare till klassrumsundervisning kvällstid. Vi erbjuder kvällsundervisning två kvällar i veckan (måndag och torsdag eller tisdag och onsdag) mellan kl. 17.30-20.30.\n\n\nBeskrivning av arbetsuppgifter\n\n\nSom lärare i svenska som andraspråk kommer du att planera, genomföra och följa upp undervisningen. Du förväntas uppmuntra elevernas kunskapsbyggande och utforskande samt bedriva en anpassad pedagogisk verksamhet utifrån både individens och gruppens behov och förutsättningar. Undervisningen bedrivs med hjälp av datorer och andra digitala hjälpmedel. Det ingår även att bidra till att utveckla skolans lärmiljö tillsammans med elever och övrig personal.\n\n\nKvalifikationer\n\n\nVi söker dig som har svensk lärarlegitimation med behörighet att undervisa i svenska som andraspråk. För att lyckas i arbetet behöver du ha it-kunskaper med inriktning mot pedagogiskt arbete och god kännedom om skolans styrdokument och läroplan. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska. Har du erfarenhet av undervisning för vuxna ses det som meriterande.\n\n\nSom person är du pedagogisk och har förståelse för människors olika förutsättningar att ta till sig kunskap. Du är utåtriktad och socialt aktiv i yrkesmässiga sammanhang. Jobbet passar dig som samarbetar och relaterar till andra på ett lyhört och smidigt sätt.\n\n\nUpplysningar\n\n\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Sabah Göransson, biträdande rektor, 018-727 44 99.\n\n\nFacklig företrädare: Sveriges lärare, Heidi Bischof, 018-727 24 51.\n\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24.\n\n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\n\n\nEn anställning hos Uppsala kommun kan komma att innebära en krigsplacering.',
#     'text_formatted': 'Välkommen till arbetsmarknadsförvaltningen. Här arbetar vi med arbetsmarknadsinsatser, försörjningsstöd, vuxenutbildning, konsumentfrågor och introduktion av nyanlända. Målet är att alla ska erbjudas möjlighet till egen försörjning. Därför arbetar vi nära näringslivet och arbetslivets parter för att öka möjligheten för personer att etablera sig på arbetsmarknaden.\n\nMer information om hur det är att arbeta i Uppsala kommun hittar du på https://www.uppsala.se/jobb/\r\n\r\nÄr du lärare i svenska som andraspråk och vill vara med och ge vuxna möjligheten att studera?\xa0 Gillar du att uppmuntra elevernas kunskapsbyggande och utforskande? Då kan det här vara jobbet för dig!\n\n\nUtbildnings- och jobbcenter i Uppsala är en kommunal vuxenutbildning belägen på flera adresser i Uppsala. Vi erbjuder vuxna möjligheten att studera svenska för invandrare (SFI), allmänna ämnen på grundläggande och gymnasial nivå, yrkesutbildningar samt komvux som anpassad utbildning.\n\n\nVåra kurser bedrivs i form av närundervisning och flexibla former. Utbildnings- och jobbcenter driver också ett lärcentrum i Gottsunda.\n\n\nVi arbetar aktivt med att integrera digital teknik i undervisningen. Alla lärare har tillgång till egen laptop och skolan är välutrustad med smartboards i alla klassrum. Vårt lärarlag präglas av flexibilitet och samarbete och pedagogiska diskussioner.\n\n\nGenom den här annonsen söker vi flera lärare till klassrumsundervisning kvällstid. Vi erbjuder kvällsundervisning två kvällar i veckan (måndag och torsdag eller tisdag och onsdag) mellan kl. 17.30-20.30.\n\n\nBeskrivning av arbetsuppgifter\n\n\nSom lärare i svenska som andraspråk kommer du att planera, genomföra och följa upp undervisningen. Du förväntas uppmuntra elevernas kunskapsbyggande och utforskande samt bedriva en anpassad pedagogisk verksamhet utifrån både individens och gruppens behov och förutsättningar. Undervisningen bedrivs med hjälp av datorer och andra digitala hjälpmedel. Det ingår även att bidra till att utveckla skolans lärmiljö tillsammans med elever och övrig personal.\n\n\nKvalifikationer\n\n\nVi söker dig som har svensk lärarlegitimation med behörighet att undervisa i svenska som andraspråk. För att lyckas i arbetet behöver du ha it-kunskaper med inriktning mot pedagogiskt arbete och god kännedom om skolans styrdokument och läroplan. Arbetet kräver att du har goda muntliga och skriftliga kunskaper i svenska. Har du erfarenhet av undervisning för vuxna ses det som meriterande.\n\n\nSom person är du pedagogisk och har förståelse för människors olika förutsättningar att ta till sig kunskap. Du är utåtriktad och socialt aktiv i yrkesmässiga sammanhang. Jobbet passar dig som samarbetar och relaterar till andra på ett lyhört och smidigt sätt.\n\n\nUpplysningar\n\n\nHar du frågor om tjänsten eller rekryteringsprocessen, kontakta: Sabah Göransson, biträdande rektor, 018-727 44 99.\n\n\nFacklig företrädare: Sveriges lärare, Heidi Bischof, 018-727 24 51.\n\n\nHar du frågor gällande registrering av din ansökan, kontakta enheten för kompetensförsörjning: 018-727 68 24.\n\n\nI din ansökan ska du ange medborgarskap. Om du inte är medborgare i Sverige, EU, EES eller Schweiz måste du också kunna styrka att du har ett giltigt arbetstillstånd eller är undantagen från skyldigheten att ha arbetstillstånd. Anställning kan ske först efter kontroll av arbetstillstånd, vilket krävs enligt utlänningsförordningen.\n\n\nEn anställning hos Uppsala kommun kan komma att innebära en krigsplacering. \xa0',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid / deltid. \r\nTidsbegränsad anställning, tillträde: Enligt överenskommelse.'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Månadslön',
#    'duration': {'concept_id': 'Xj7x_7yZ_jEn',
#     'label': '3 månader – upp till 6 månader',
#     'legacy_ams_taxonomy_id': '3'},
#    'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#     'label': 'Deltid',
#     'legacy_ams_taxonomy_id': '2'},
#    'scope_of_work': {'min': 0, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2120003005',
#     'name': 'Uppsala kommun',
#     'workplace': 'Uppsala kommun, Vuxenutbildning'},
#    'application_details': {'information': None,
#     'reference': 'AMN-2025-00530',
#     'email': None,
#     'via_af': False,
#     'url': 'https://recruit.visma.com/spa/public/apply?guidAssignment=4d54633a-c0b3-4fbd-997d-9fb8b9619c59&publishCode=AMS&TK=d7997b67-099a-49f6-bc15-6fe9b2a05931',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '15e8_KDZ_31Z',
#     'label': 'SFI-lärare',
#     'legacy_ams_taxonomy_id': '7382'},
#    'occupation_group': {'concept_id': 'mcRJ_kq2_jFr',
#     'label': 'Övriga pedagoger med teoretisk specialistkompetens',
#     'legacy_ams_taxonomy_id': '2359'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [17.638927, 59.858562]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Sabah Göransson',
#      'email': None,
#      'telephone': '018-727 44 99',
#      'contact_type': 'Biträdande rektor'}],
#    'publication_date': '2025-08-25T13:40:27',
#    'last_publication_date': '2025-09-07T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1756122027634},
#   {'relevance': 0.5623389429784517,
#    'id': '29960043',
#    'external_id': '46-202100-4615-44784',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29960043',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/2021004615/logotyper/logo.png',
#    'headline': 'Lärare luftbevakning Utbildningsavdelningen StrilS',
#    'application_deadline': '2025-09-26T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Lärare luftbevakning Utbildningsavdelningen StrilS\n \n \nÄr du intresserad av utbildning och simulatorer samt utveckling av dessa? Vill du vara med och påverka Sveriges försvarsförmåga? I så fall har vi en plats för dig – tillsammans skapar vi förutsättningar för Flygvapnets personaluppfyllnad och taktiska utveckling.\n\n\xa0\n\nStridslednings- och luftbevakningsskolan (StrilS)\n\n StrilS är flygvapnets stridslednings- och luftbevakningsskola. Skolan bedriver grundläggande officersutbildning mot såväl officer- som specialistofficer inom flygstridslednings-, luftbevaknings- och sambandstjänst samt övrig kompetensutveckling för stridslednings- och luftbevakningsorganisationens behov. Skolan är dessutom sammanhållande för utbildning av\xa0 specialistofficerare i underrättelsetjänst, för flygvapnets behov.\n\n\xa0\n\nHuvudsakliga arbetsuppgifter\n\nSom lärare inom lufbevakning på Utbildningsavdelningen kommer du främst att bedriva utbildning inom luftbevakningsfunktionen. Du kommer att utbilda elever inom ramen för såväl programbunden utbildning som YBK:er. I rollen som lärare kommer du även att ha ett stort uppföljningsansvar och kontinueligt utvärdera eleverna och ge konstruktiv feedback.\n\nStrilS utbildar kadetter inom ramen för såväl officers- som specialistofficersprogrammet. Du kommer att få inblick i skillnaderna i exempelvis regelverk för de olika utbildningarna kopplat mot våra skolans kurser.\n\nDu kan komma att vara med i utvecklingen av C2Strics och C2StriC, bland annat genom att deltaga på tester och möten hos tillverkaren på uppdrag av Försvarsmaktens materielverk, FMV.\n\nUtöver nämnda uppgifter kan du även komma att stötta 161.strilbataljonen i delar av deras verksamhet inom ramen för incidentberedskap.\n\n\n Personliga egenskaper\n\n Att du är noggrann, prestigelös och en god lagspelare gör att du har rätt förutsättningar för att lösa dina arbetsuppgifter. Du är social och utåtriktad med hög kommunikatov förmåga och känner dig trygg med att arbeta såväl självständigt som tillsammans med andra. Du är flexibel och kan hantera tillfälliga toppar i arbetsbelastning utan att bli stressad.\n\nVid urval kommer stor vikt läggas vid personliga egenskaper och lämplighet.\n\n\xa0\n\nKRAV\n Kvalifikationer\n\n\n• Yrkesofficer\n• Behörig luftbevakningsoperatör\n• God pedagogisk förmåga\n\n\xa0\n\nMERITERANDE\n\n\n• Genomfört StrilS instruktörskurs\n• Tidigare verksam som lärare på StrilS\n• Genomfört Krig 1 & 2 på StrilS med godkänt resultat\n\n\xa0\n\nFör att myndighetens uppdrag ska vara framgångsrikt förutsätts att alla medarbetare uppträder enligt den värdegrund som finns. Försvarsmaktens värdegrund slår vakt om alla människors lika värde, rättvisa och jämlikhet och främjar demokrati och mänskliga rättigheter (läs mer på www.forsvarsmakten.se).\n\n\xa0\n\nÖvrigt\n\n Anställningsform: Tillsvidare\n Sysselsättningsgrad: Heltid\n Arbetsort: Uppsala\n Militär befattning \n Tjänsten innebär internationell tjänstgöringsskyldighet, krigsplacering samt deltagande i utbildning och övning i krigsorganisation.\n Tillträdesdatum: Snarast eller enligt överenskommelse.\n\n\n Upplysningar om befattningen och rekryteringsprocessen\n Erik Lundh, tel. 076-867 18 95\n\n\xa0\n\nFackliga företrädare\n\nOFR/O Ärna Tim Björklund, tfn 070-649 65 59\n OFR/S & Försvarsförbundet Helena Lemnell tfn 070-836 10 28\n SEKO Åsa Karlsson nås via vx 018-19 60 00\n SACO nås via vx 018-19 60 00\n\n\xa0\n\nVälkommen med din ansökan senast 2025-09-26.\n \n Din ansökan bör innehålla CV samt ansökningsbrev där du motiverar varför du är lämpad för denna befattning. \n\n\xa0\n\n Ansökningar till denna befattning kommer endast tas emot via Försvarsmaktens webbplats. \n--------------------------------------------------------\nInformation om Försvarsmakten och det rekryterande förbandet:\n\nLuftstridsskolan är flygvapnets gemensamma kompetenscentrum för utveckling och utbildning. Luftstridsskolan har fyra flygvapengemensamma skolor och ut ...
#     'text_formatted': 'Lärare luftbevakning Utbildningsavdelningen StrilS\n \n \nÄr du intresserad av utbildning och simulatorer samt utveckling av dessa? Vill du vara med och påverka Sveriges försvarsförmåga? I så fall har vi en plats för dig – tillsammans skapar vi förutsättningar för Flygvapnets personaluppfyllnad och taktiska utveckling.\n\n\xa0\n\nStridslednings- och luftbevakningsskolan (StrilS)\n\n StrilS är flygvapnets stridslednings- och luftbevakningsskola. Skolan bedriver grundläggande officersutbildning mot såväl officer- som specialistofficer inom flygstridslednings-, luftbevaknings- och sambandstjänst samt övrig kompetensutveckling för stridslednings- och luftbevakningsorganisationens behov. Skolan är dessutom sammanhållande för utbildning av\xa0 specialistofficerare i underrättelsetjänst, för flygvapnets behov.\n\n\xa0\n\nHuvudsakliga arbetsuppgifter\n\nSom lärare inom lufbevakning på Utbildningsavdelningen kommer du främst att bedriva utbildning inom luftbevakningsfunktionen. Du kommer att utbilda elever inom ramen för såväl programbunden utbildning som YBK:er. I rollen som lärare kommer du även att ha ett stort uppföljningsansvar och kontinueligt utvärdera eleverna och ge konstruktiv feedback.\n\nStrilS utbildar kadetter inom ramen för såväl officers- som specialistofficersprogrammet. Du kommer att få inblick i skillnaderna i exempelvis regelverk för de olika utbildningarna kopplat mot våra skolans kurser.\n\nDu kan komma att vara med i utvecklingen av C2Strics och C2StriC, bland annat genom att deltaga på tester och möten hos tillverkaren på uppdrag av Försvarsmaktens materielverk, FMV.\n\nUtöver nämnda uppgifter kan du även komma att stötta 161.strilbataljonen i delar av deras verksamhet inom ramen för incidentberedskap.\n\n\n Personliga egenskaper\n\n Att du är noggrann, prestigelös och en god lagspelare gör att du har rätt förutsättningar för att lösa dina arbetsuppgifter. Du är social och utåtriktad med hög kommunikatov förmåga och känner dig trygg med att arbeta såväl självständigt som tillsammans med andra. Du är flexibel och kan hantera tillfälliga toppar i arbetsbelastning utan att bli stressad.\n\nVid urval kommer stor vikt läggas vid personliga egenskaper och lämplighet.\n\n\xa0\n\nKRAV\n Kvalifikationer\n\n\n• Yrkesofficer\n• Behörig luftbevakningsoperatör\n• God pedagogisk förmåga\n\n\xa0\n\nMERITERANDE\n\n\n• Genomfört StrilS instruktörskurs\n• Tidigare verksam som lärare på StrilS\n• Genomfört Krig 1 &amp; 2 på StrilS med godkänt resultat\n\n\xa0\n\nFör att myndighetens uppdrag ska vara framgångsrikt förutsätts att alla medarbetare uppträder enligt den värdegrund som finns. Försvarsmaktens värdegrund slår vakt om alla människors lika värde, rättvisa och jämlikhet och främjar demokrati och mänskliga rättigheter (läs mer på www.forsvarsmakten.se).\n\n\xa0\n\nÖvrigt\n\n Anställningsform: Tillsvidare\n Sysselsättningsgrad: Heltid\n Arbetsort: Uppsala\n Militär befattning \n Tjänsten innebär internationell tjänstgöringsskyldighet, krigsplacering samt deltagande i utbildning och övning i krigsorganisation.\n Tillträdesdatum: Snarast eller enligt överenskommelse.\n\n\n Upplysningar om befattningen och rekryteringsprocessen\n Erik Lundh, tel. 076-867 18 95\n\n\xa0\n\nFackliga företrädare\n\nOFR/O Ärna Tim Björklund, tfn 070-649 65 59\n OFR/S &amp; Försvarsförbundet Helena Lemnell tfn 070-836 10 28\n SEKO Åsa Karlsson nås via vx 018-19 60 00\n SACO nås via vx 018-19 60 00\n\n\xa0\n\nVälkommen med din ansökan senast 2025-09-26.\n \n Din ansökan bör innehålla CV samt ansökningsbrev där du motiverar varför du är lämpad för denna befattning. \n\n\xa0\n\n Ansökningar till denna befattning kommer endast tas emot via Försvarsmaktens webbplats. \n--------------------------------------------------------\nInformation om Försvarsmakten och det rekryterande förbandet:\n\nLuftstridsskolan är flygvapnets gemensamma kompetenscentrum för utveckling och utbildning. Luftstridsskolan har fyra flygvapengemensamma skolor och ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid/\r\nEj specificerat'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Individuell lönesättning.',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '2021004615',
#     'name': 'Försvarsmakten',
#     'workplace': 'Försvarsmakten'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://go.talentech.io/bYqqv',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'fsDP_fPf_xfC',
#     'label': 'Officer',
#     'legacy_ams_taxonomy_id': '5541'},
#    'occupation_group': {'concept_id': 'KiVA_anS_RJh',
#     'label': 'Officerare',
#     'legacy_ams_taxonomy_id': '0110'},
#    'occupation_field': {'concept_id': 'bH5L_uXD_ZAX',
#     'label': 'Militära yrken',
#     'legacy_ams_taxonomy_id': '22'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
# ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Deltid - Enligt ?verenskommelse\r\nTillf?lligt arbete, 11 dagar - 3 m?nader'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Fast l?n',
#    'duration': {'concept_id': 'Sy9J_aRd_ALx',
#     'label': '11 dagar - upp till 3 månader',
#     'legacy_ams_taxonomy_id': '7'},
#    'working_hours_type': {'concept_id': '947z_JGS_Uk2',
#     'label': 'Deltid',
#     'legacy_ams_taxonomy_id': '2'},
#    'scope_of_work': {'min': 0, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'http://www.clockworkpersonal.se',
#     'organization_number': '5569137325',
#     'name': 'Clockwork Bemanning & Rekrytering AB',
#     'workplace': 'Clockwork Skolbemanning & Rekrytering AB '},
#    'application_details': {'information': None,
#     'reference': '10269',
#     'email': None,
#     'via_af': False,
#     'url': 'http://clockworkpersonal.se/jobb/?jaid=10269&apply=true',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'iYgm_hfD_Bez',
#     'label': 'Ämneslärare, 7-9',
#     'legacy_ams_taxonomy_id': '7654'},
#    'occupation_group': {'concept_id': 'oQUQ_D11_HPx',
#     'label': 'Grundskollärare',
#     'legacy_ams_taxonomy_id': '2341'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [17.638927, 59.858562]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'iYgm_hfD_Bez',
#       'label': 'Ämneslärare, 7-9',
#       'legacy_ams_taxonomy_id': '7654'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Jonny Gebara',
#      'email': 'jonny.gebara@clwork.se',
#      'telephone': None,
#      'contact_type': None}],
#    'publication_date': '2025-08-14T10:20:58',
#    'last_publication_date': '2025-08-29T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1755159658998},
#   {'relevance': 0.5623389429784517,
#    'id': '29696902',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29696902',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/arbetsplatser/87999210/logotyper/logo.png',
#    'headline': 'Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!',
#    'application_deadline': '2025-10-31T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Hjärtligt välkommen att arbeta som lärare tillsammans med oss på PersonalExpressen Lärarbemanning!\nPersonalExpressen är ett bemanningsföretag som finns till för att skapa en positiv skillnad för människor i deras liv, inte minst för alla de lärare som arbetar tillsammans med oss ute på någon av landets många skolor. Vårt ledord är kvalitet och det viktigaste för oss är att du som vår lärare trivs med dina arbetsuppgifter, samtidigt som du känner att du ges möjlighet att utvecklas på det personliga planet när du arbetar tillsammans med oss!\nVi samarbetar idag med många skolor runt om i hela landet, såväl kommunala som privata. Hos oss kommer du garanterat att finna en plats att trivas på över tid där du samtidigt får det bästa stöd du kan tänka dig från oss som arbetar centralt på PersonalExpressen. Vi ser alltid till att du får det stöd du behöver både i din yrkesroll som lärare i allmänhet samtidigt som vi ser till att du får det stöd du behöver kopplat till specifika saker som sker på plats ute i den skolverksamhet där du arbetar som bemanningskonsult genom oss.\nDu som söker en ny utmaning i ditt yrkesliv som lärare samtidigt som du vill vara en del i en arbetsmiljö där du känner dig sedd, uppskattad och respekterad av dina kollegor kommer att passa in perfekt hos oss!\nArbeta på dina egna villkor med högre lön!\nDet finns två olika sätt att arbeta på när man är anställd som lärare hos oss. Det första alternativet innebär att du styr helt och hållet själv över din egen arbetstid där du anmäler dig som tillgänglig i vår app de dagar du själv vill arbeta. Genom detta kan du då bli bokad på olika dagsvikariat på olika skolor olika dagar. Det här ger dig en unik möjlighet att testa på att arbeta på olika arbetsplatser genom oss innan du väljer var du trivs bäst. Det går också utmärkt att kombinera detta alternativ med t.ex. studier eller med andra jobb när du i första hand är intresserad av att arbeta extra till en högre lön på de tider som passar dig.\nDet andra alternativet innebär att du anmäler intresse till oss för ett längre uppdrag, såsom ett års- eller terminsuppdrag. Vi får många förfrågningar till oss löpande som varierar i både tjänstgöringsgrad och uppdragstid. Genom dessa två olika alternativ att arbeta med oss kommer du alltid att få ett uppdrag som passar just dig - oavsett hur du själv föredrar att jobba. Det går också utmärkt att variera mellan vilket av de två alternativen du föredrar. Många som jobbar tillsammans med oss väljer till exempel att arbeta på ett heltidsschema vissa delar av året för att andra delar av året arbeta lite mindre. Hos oss får du friheten att välja själv samt ett större utrymme att ge ditt privatliv prioritet under de perioder som det är viktigast för dig - vi är lyhörda som arbetsgivare och gör allt för att våra medarbetare ska trivas hos oss över lång tid!\nUtöver friheten att välja själv hur du vill arbeta kommer du hos oss alltid att få en högre lön och bättre villkor än om du är anställd som lärare någon annanstans. Vi är framtidens arbetsgivare och vi förstår att du värdesätter en arbetsgivare högt som värdesätter dig högt tillbaka och som är beredd att kämpa för dig och dina arbetsvillkor - något våra skickliga förhandlare alltid kommer att göra för dig inför varje nytt läraruppdrag du påbörjar hos någon av de många skolor vi samarbetar med.\nVi har läraruppdrag att erbjuda inom alla skolämnen och alla årskurser!\nPå PersonalExpressen har vi läraruppdrag att erbjuda inom alla skolämnen och alla årskurser. Hos oss hittar du alltid hem oavsett om du kan undervisa i SO-ämnena, NO-ämnena, språkämnena, idrott, musik eller något annat. Våra samarbetsskolor återfinns över hela Sverige!\nSök in till oss på PersonalExpressen redan idag!\nÅterigen hjärtligt välkommen till oss på PersonalExpressen Lärarbemanning - vi ser fram emot att få börja arbeta tillsammans med dig och förhoppningsvis även att inom kort få hitta ditt första läraruppdrag genom oss!',
#     'text_formatted': '<p><br></p><p><strong>Hjärtligt välkommen att arbeta som lärare tillsammans med oss på PersonalExpressen Lärarbemanning!</strong></p><p>PersonalExpressen är ett bemanningsföretag som finns till för att skapa en positiv skillnad för människor i deras liv, inte minst för alla de lärare som arbetar tillsammans med oss ute på någon av landets många skolor. Vårt ledord är kvalitet och det viktigaste för oss är att du som vår lärare trivs med dina arbetsuppgifter, samtidigt som du känner att du ges möjlighet att utvecklas på det personliga planet när du arbetar tillsammans med oss!</p><p>Vi samarbetar idag med många skolor runt om i hela landet, såväl kommunala som privata. Hos oss kommer du garanterat att finna en plats att trivas på över tid där du samtidigt får det bästa stöd du kan tänka dig från oss som arbetar centralt på PersonalExpressen. Vi ser alltid till att du får det stöd du behöver både i din yrkesroll som lärare i allmänhet samtidigt som vi ser till att du får det stöd du behöver kopplat till specifika saker som sker på plats ute i den skolverksamhet där du arbetar som bemanningskonsult genom oss.</p><p>Du som söker en ny utmaning i ditt yrkesliv som lärare samtidigt som du vill vara en del i en arbetsmiljö där du känner dig sedd, uppskattad och respekterad av dina kollegor kommer att passa in perfekt hos oss!</p><p><strong>Arbeta på dina egna villkor med högre lön!</strong></p><p>Det finns två olika sätt att arbeta på när man är anställd som lärare hos oss. Det första alternativet innebär att du styr helt och hållet själv över din egen arbetstid där du anmäler dig som tillgänglig i vår app de dagar du själv vill arbeta. Genom detta kan du då bli bokad på olika dagsvikariat på olika skolor olika dagar. Det här ger dig en unik möjlighet att testa på att arbeta på olika arbetsplatser genom oss innan du väljer var du trivs bäst. Det går också utmärkt att kombinera detta alternativ med t.ex. studier eller med andra jobb när du i första hand är intresserad av att arbeta extra till en högre lön på de tider som passar dig.</p><p>Det andra alternativet innebär att du anmäler intresse till oss för ett längre uppdrag, såsom ett års- eller terminsuppdrag. Vi får många förfrågningar till oss löpande som varierar i både tjänstgöringsgrad och uppdragstid. Genom dessa två olika alternativ att arbeta med oss kommer du alltid att få ett uppdrag som passar just dig - oavsett hur du själv föredrar att jobba. Det går också utmärkt att variera mellan vilket av de två alternativen du föredrar. Många som jobbar tillsammans med oss väljer till exempel att arbeta på ett heltidsschema vissa delar av året för att andra delar av året arbeta lite mindre. Hos oss får du friheten att välja själv samt ett större utrymme att ge ditt privatliv prioritet under de perioder som det är viktigast för dig - vi är lyhörda som arbetsgivare och gör allt för att våra medarbetare ska trivas hos oss över lång tid!</p><p>Utöver friheten att välja själv hur du vill arbeta kommer du hos oss alltid att få en högre lön och bättre villkor än om du är anställd som lärare någon annanstans. Vi är framtidens arbetsgivare och vi förstår att du värdesätter en arbetsgivare högt som värdesätter dig högt tillbaka och som är beredd att kämpa för dig och dina arbetsvillkor - något våra skickliga förhandlare alltid kommer att göra för dig inför varje nytt läraruppdrag du påbörjar hos någon av de många skolor vi samarbetar med.</p><p><strong>Vi har läraruppdrag att erbjuda inom alla skolämnen och alla årskurser!</strong></p><p>På PersonalExpressen har vi läraruppdrag att erbjuda inom alla skolämnen och alla årskurser. Hos oss hittar du alltid hem oavsett om du kan undervisa i SO-ämnena, NO-ämnena, språkämnena, idrott, musik eller något annat. Våra samarbetsskolor återfinns över hela Sverige!</p><p><strong>Sök in till oss på PersonalExpressen redan idag!</strong></p><p>Återigen hjärtligt välkommen till oss på PersonalExpressen Lärarbemanning - vi ser fram emot ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5591070213',
#     'name': 'PersonalExpressen AB',
#     'workplace': 'Uppsala'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://personalexpressen.weselect.com/p/46425-larare',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'f8q7_Rwv_TP4',
#     'label': 'Lärare i gymnasieskolan',
#     'legacy_ams_taxonomy_id': '7127'},
#    'occupation_group': {'concept_id': '4KhP_FxL_uZ5',
#     'label': 'Gymnasielärare',
#     'legacy_ams_taxonomy_id': '2330'},
#    'occupation_field': {'concept_id': 'MVqp_eS8_kDZ',
#     'label': 'Pedagogik',
#     'legacy_ams_taxonomy_id': '15'},
#    'workplace_address': {'municipality': 'Uppsala',
#     'municipality_code': '0380',
#     'municipality_concept_id': 'otaF_bQY_4ZD',
#     'region': 'Uppsala län',
#     'region_code': '03',
#     'region_concept_id': 'zBon_eET_fFU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-05-12T16:29:49',
#    'last_publication_date': '2025-10-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1747060189145}]}

# %%
json_response.keys()
# Out:
# dict_keys(['total', 'positions', 'query_time_in_millis', 'result_time_in_millis', 'stats', 'freetext_concepts', 'hits'])

# %%
len(json_response["hits"])
# Out:
# 11

# %%
json_response["hits"][1].keys()
# Out:
# dict_keys(['relevance', 'id', 'external_id', 'original_id', 'label', 'webpage_url', 'logo_url', 'headline', 'application_deadline', 'number_of_vacancies', 'description', 'employment_type', 'salary_type', 'salary_description', 'duration', 'working_hours_type', 'scope_of_work', 'access', 'employer', 'application_details', 'experience_required', 'access_to_own_car', 'driving_license_required', 'driving_license', 'occupation', 'occupation_group', 'occupation_field', 'workplace_address', 'must_have', 'nice_to_have', 'application_contacts', 'publication_date', 'last_publication_date', 'removed', 'removed_date', 'source_type', 'timestamp'])

# %%
json_response["hits"][1]["headline"]
# Out:
# 'JENSEN gymnasium Uppsala söker lärare i matematik/engelska'

# %%
json_response = _get_ads({"q": "data engineer", "limit": 100})
#json_response
# Out:
# {'total': {'value': 80},
#  'positions': 101,
#  'query_time_in_millis': 12,
#  'result_time_in_millis': 298,
#  'stats': [],
#  'freetext_concepts': {'skill': [],
#   'occupation': ['data engineer'],
#   'location': [],
#   'skill_must': [],
#   'occupation_must': [],
#   'location_must': [],
#   'skill_must_not': [],
#   'occupation_must_not': [],
#   'location_must_not': []},
#  'hits': [{'relevance': 1.0,
#    'id': '29963199',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29963199',
#    'logo_url': None,
#    'headline': 'Data Engineer',
#    'application_deadline': '2025-09-27T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'At RELEX, Engineering means to tackle complex challenges with cutting-edge tools and a forward-thinking approach. The work is complex, and it’s rewarding. From managing massive datasets to building user interfaces, we push boundaries to create intuitive software. Collaboration, respect, and flexibility define how we work, become part of our community and play a role in defining its future. \nPricing & Promotions at RELEX \nWe design and develop tools that transform how businesses manage pricing and promotions, helping them make data-driven decisions with confidence. Our Pricing and Promotions applications are built cloud-native on Google Cloud Platform, combining robust Golang backend services with a seamless and intuitive Typescript/React front-end experience.  \nBehind the scenes, our data platform processes millions of rows of raw customer data using Golang workflows orchestrated by Temporal. With hybrid data layers powered by ClickHouse and Postgres, we deliver analytics and forecasts that balance pre-calculation and real-time responsiveness. We also leverage Vertex AI to enhance our machine learning capabilities, ensuring that insights are not just fast but also meaningful - helping customers plan smarter and execute better.  \nWe create solutions that are not only scalable and reliable but also designed with users in mind, offering a platform that’s intuitive and adaptable to complex business needs. Whether you’re a product professional focused on strategy or a technologist passionate about innovation, you’ll find an environment that values your expertise. \nAbout the Position:\nAs a Senior Data Engineer, you will join our Data Platform Team, working with a group of people dedicated to ensuring rapid client system integration, robust data management, and a scalable analytics engine. Our data engineers ship new functionality, integrations and infrastructure to production every day. They do not limit their scope to building an analytics platform but build mission critical systems that our customers rely on in their daily work. Together we make sure that the product is user-friendly, fast, powerful, and intuitive. \nJoin our Data Platform Team as a Senior Data Engineer, and this is some of what you’ll be doing: \nDesign and deploy data pipelines to support our business-critical systems. \nImprove the scalability of our data pipelines and wider platform to serve our growing customer base. \nSupport and improve our existing data operations with deployment tools and pipelines. \nImagine new feature ideas and design data pipelines to incorporate them into our models. \nImprove the way we evaluate and monitor our data and system performance. \n\nWe’re Looking For: \nAn advanced degree in a quantitative field (e.g., computer science, stats, physics, engineering). \nSolid experience in software engineering in a production environment. \nExperience designing and implementing applications and tooling for consolidating and processing large volumes of data. \nKnowledge on how to manipulate data to perform analysis, including querying data, defining metrics, or transforming data to effectively evaluate a hypothesis. \nExperience building integrations serving data of large scales to downstream systems, ideally to customer facing systems. \n\nAs a Senior Engineer in our organization, we also expect you to focus on results, proactively communicate and document your work, and understand the problem space before developing solutions. You will guide and unblock your team, serve as a technical resource, and seek design input when necessary.Your role includes making informed decisions about technical debt, communicating technical advice to non-technical members, and writing and driving design documents to resolution. You will coach new peers, improve code structure for testability, mentor junior members, provide actionable feedback, ensure team alignment, and help onboard new colleagues.\nLife at RELEX \nRELEX opera ...
#     'text_formatted': '<p>At RELEX, Engineering means to tackle complex challenges with cutting-edge tools and a forward-thinking approach. The work is complex, and it’s rewarding. From managing massive datasets to building user interfaces, we push boundaries to create intuitive software. Collaboration, respect, and flexibility define how we work, become part of our community and play a role in defining its future. </p><p><strong>Pricing &amp; Promotions at RELEX</strong> </p><p>We design and develop tools that transform how businesses manage pricing and promotions, helping them make data-driven decisions with confidence. Our Pricing and Promotions applications are built cloud-native on Google Cloud Platform, combining robust Golang backend services with a seamless and intuitive Typescript/React front-end experience.  </p><p>Behind the scenes, our data platform processes millions of rows of raw customer data using Golang workflows orchestrated by Temporal. With hybrid data layers powered by ClickHouse and Postgres, we deliver analytics and forecasts that balance pre-calculation and real-time responsiveness.<strong> </strong>We also leverage Vertex AI to enhance our machine learning capabilities, ensuring that insights are not just fast but also meaningful - helping customers plan smarter and execute better.  </p><p>We create solutions that are not only scalable and reliable but also designed with users in mind, offering a platform that’s intuitive and adaptable to complex business needs. Whether you’re a product professional focused on strategy or a technologist passionate about innovation, you’ll find an environment that values your expertise. </p><p><strong>About the Position:</strong></p><p>As a <strong>Senior Data Engineer,</strong> you will join our Data Platform Team, working with a group of people dedicated to ensuring rapid client system integration, robust data management, and a scalable analytics engine. Our data engineers ship new functionality, integrations and infrastructure to production every day. They do not limit their scope to building an analytics platform but build mission critical systems that our customers rely on in their daily work. Together we make sure that the product is user-friendly, fast, powerful, and intuitive. </p><p><strong>Join our Data Platform Team as a Senior Data Engineer, and this is some of what you’ll be doing:</strong> </p><ul><li>Design and deploy data pipelines to support our business-critical systems. </li><li>Improve the scalability of our data pipelines and wider platform to serve our growing customer base. </li><li>Support and improve our existing data operations with deployment tools and pipelines. </li><li>Imagine new feature ideas and design data pipelines to incorporate them into our models. </li><li>Improve the way we evaluate and monitor our data and system performance. </li></ul><p><strong>We’re Looking For:</strong> </p><ul><li>An advanced degree in a quantitative field (e.g., computer science, stats, physics, engineering). </li><li>Solid experience in software engineering in a production environment. </li><li>Experience designing and implementing applications and tooling for consolidating and processing large volumes of data. </li><li>Knowledge on how to manipulate data to perform analysis, including querying data, defining metrics, or transforming data to effectively evaluate a hypothesis. </li><li>Experience building integrations serving data of large scales to downstream systems, ideally to customer facing systems. </li></ul><p>As a Senior Engineer in our organization, we also expect you to focus on results, proactively communicate and document your work, and understand the problem space before developing solutions. You will guide and unblock your team, serve as a technical resource, and seek design input when necessary.Your role includes making informed decisions about technical debt, communicating technical advice to non-technical members, and writing and driving d ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5569396129',
#     'name': 'Formulate AB',
#     'workplace': 'Formulate AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'http://relexsolutions.com',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9jYT_DS5_6JE',
#     'label': 'Systemdesigner',
#     'legacy_ams_taxonomy_id': '2413'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': None,
#     'municipality_code': None,
#     'municipality_concept_id': None,
#     'region': None,
#     'region_code': None,
#     'region_concept_id': None,
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 5,
#       'concept_id': '9jYT_DS5_6JE',
#       'label': 'Systemdesigner',
#       'legacy_ams_taxonomy_id': '2413'}],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-08-28T22:58:40',
#    'last_publication_date': '2025-09-27T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1756414720696},
#   {'relevance': 1.0,
#    'id': '29949485',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29949485',
#    'logo_url': None,
#    'headline': 'Data Engineer',
#    'application_deadline': '2025-09-25T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Job Description\nDo you want to be part of implementing a new scalable data foundation at H&M? We are looking for an experienced Data Engineer who thrives on solving complex challenges and building impactful solutions. As part of our team, you will play a critical role in creating data products that drive business decisions across all H&M. You’ll design and develop next-generation data and analytics solutions, focusing on enabling smart, self-service capabilities. \n\n\nH&M is transforming the fashion retail industry through innovation, data, and technology. In this role, you’ll contribute to one of the largest data transformation initiatives within the company, working with Data Mesh concepts to build data products that meet global needs.\nOur team is part of the Data Engineering unit within our tech center, AI, Analytics & Data. The area supports all our brands globally to create, structure, guard and ensure data is available, understandable and of high quality. \nKey responsibilities \nIndependently develop and optimize complex data pipelines, ensuring smooth data flow across multiple domains. \nUtilize complex SQL querying techniques to extract, manipulate, and analyze data for various business needs. \nConfidently use programming languages such as Java or Python to write classes, functions, and apply object-oriented programming principles, along with basic unit testing. \nGuide junior Data Engineers on tasks and best practices, effectively delegating to promote team growth. \nUnderstand business issues, create data-driven solutions, and present them to stakeholders, ensuring alignment with goals. \nIdentify optimization opportunities in data systems, plan implementations, and develop risk mitigation strategies. \nWork with stakeholders and teams to drive data initiatives, providing leadership and contributing to the organization’s data strategy. \n\n\n\nQualifications\nRelevant academic degree in any technical field\u202fin\u202fBSc, BE or a related field \n3-6 years of working experience in Data Engineering with strong experience in SQL, Python, or similar languages \nProficient in data modelling, warehousing, pipeline development, and documentation \nExperience with production methodologies, software development principles, and Agile practices \nUnderstanding of business needs related to the product scope \nDeep understanding of cloud technologies and cloud development, as well as ability to select appropriate\u202f(cost-effective) tools for different tasks \nHave a collaborative and co-creative mindset with excellent communication skills \nMotivated to work in an environment that allows you to work and take decisions independently \nExperience in working with data visualization tools \nFluent in English both written and verbal \n\n \nAdvantage if you also have: \nExperience in GCP tools – Bigquery, Cloud run, Cloud functions, Pubsub, Dataflow, Cloud composer\nExperience in data processing framework – Beam, Spark, Hive, Flink \nBusiness understanding of retail industry \n\nOur journey will lead to something new and exciting - we will test, fail, and learn. You are an important player in this transformation; therefore, we believe you are flexible, stress-resistant, and able to work in an environment that is ever changing. \n\n\nAdditional Information\nThis is a permanent, full-time position based in Stockholm, Sweden. The role is on-site in our offices in Marievik with flexibility for hybrid work. \nPlease submit your CV in English. \nDue to data policies, we can only accept applications through our career page. \nBenefits \nWe offer all our employees a comprehensive benefits package, including global and local offerings. \nInclusion & Diversity \nAt H&M Group, we’re committed to creating an inclusive and diverse workplace. We welcome applications from people of all backgrounds, experiences, and perspectives.',
#     'text_formatted': '<p><strong>Job Description</strong></p><p>Do you want to be part of implementing a new scalable data foundation at H&amp;M? We are looking for an experienced Data Engineer who thrives on solving complex challenges and building impactful solutions. As part of our team, you will play a critical role in creating data products that drive business decisions across all H&amp;M. You’ll design and develop next-generation data and analytics solutions, focusing on enabling smart, self-service capabilities. </p><p><br></p><p>H&amp;M is transforming the fashion retail industry through innovation, data, and technology. In this role, you’ll contribute to one of the largest data transformation initiatives within the company, working with Data Mesh concepts to build data products that meet global needs.</p><p>Our team is part of the Data Engineering unit within our tech center, AI, Analytics &amp; Data. The area supports all our brands globally to create, structure, guard and ensure data is available, understandable and of high quality. </p><p><strong>Key responsibilities </strong></p><ul><li>Independently develop and optimize complex data pipelines, ensuring smooth data flow across multiple domains. </li><li>Utilize complex SQL querying techniques to extract, manipulate, and analyze data for various business needs. </li><li>Confidently use programming languages such as Java or Python to write classes, functions, and apply object-oriented programming principles, along with basic unit testing. </li><li>Guide junior Data Engineers on tasks and best practices, effectively delegating to promote team growth. </li><li>Understand business issues, create data-driven solutions, and present them to stakeholders, ensuring alignment with goals. </li><li>Identify optimization opportunities in data systems, plan implementations, and develop risk mitigation strategies. </li><li>Work with stakeholders and teams to drive data initiatives, providing leadership and contributing to the organization’s data strategy. </li></ul><p><br></p><p><strong>Qualifications</strong></p><ul><li>Relevant academic degree in any technical field\u202fin\u202fBSc, BE or a related field </li><li>3-6 years of working experience in Data Engineering with strong experience in SQL, Python, or similar languages </li><li>Proficient in data modelling, warehousing, pipeline development, and documentation </li><li>Experience with production methodologies, software development principles, and Agile practices </li><li>Understanding of business needs related to the product scope </li><li>Deep understanding of cloud technologies and cloud development, as well as ability to select appropriate\u202f(cost-effective) tools for different tasks </li><li>Have a collaborative and co-creative mindset with excellent communication skills </li><li>Motivated to work in an environment that allows you to work and take decisions independently </li><li>Experience in working with data visualization tools </li><li>Fluent in English both written and verbal </li></ul><p> </p><p>Advantage if you also have: </p><ul><li>Experience in GCP tools – Bigquery, Cloud run, Cloud functions, Pubsub, Dataflow, Cloud composer</li><li>Experience in data processing framework – Beam, Spark, Hive, Flink </li><li>Business understanding of retail industry </li></ul><p>Our journey will lead to something new and exciting - we will test, fail, and learn. You are an important player in this transformation; therefore, we believe you are flexible, stress-resistant, and able to work in an environment that is ever changing. </p><p><br></p><p><strong>Additional Information</strong></p><p>This is a permanent, full-time position based in Stockholm, Sweden. The role is on-site in our offices in Marievik with flexibility for hybrid work. </p><p>Please submit your CV in English. </p><p>Due to data policies, we can only accept applications through our career page. </p><p><strong>Benefits </strong></p><p>We offer all our employe ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5560701715',
#     'name': 'H & M Hennes & Mauritz Gbc AB',
#     'workplace': 'H & M Hennes & Mauritz Gbc AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://jobs.smartrecruiters.com/HMGroup/744000077901707-data-engineer',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Årstaängsvägen 13',
#     'postcode': '10638',
#     'city': 'Stockholm',
#     'coordinates': [18.0528391, 59.2877928]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-08-26T10:23:20',
#    'last_publication_date': '2025-09-25T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1756196600667},
#   {'relevance': 1.0,
#    'id': '29935963',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29935963',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/arbetsplatser/87420686/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2025-11-19T23:59:59',
#    'number_of_vacancies': 5,
#    'description': {'text': "Data Engineer\nWe're seeking a Data Engineer with experience in cloud platforms, machine learning pipelines, and time-series data, ideally within automotive or sensor-heavy environments.\nWhat You’ll Do\nBuild and optimize data pipelines for large-scale vehicle and sensor data\nDeploy scalable ML workflows using AWS, PySpark, and Terraform\nSupport data scientists with clean, structured, and accessible datasets\nDevelop dashboards and reporting tools (QuickSight, Power BI)\n\nYour Background\nMaster’s in Data Science or similar\nSkilled in Python, AWS, PySpark, Terraform, and signal processing\nExperience with vehicle data, cloud infrastructure, or ML pipelines\nStrong analytical and problem-solving mindset\n\n\n\nPlease send Your CV to jobs@telescopeservices.se.",
#     'text_formatted': "<p><strong>Data Engineer</strong></p><p>We're seeking a <strong>Data Engineer</strong> with experience in cloud platforms, machine learning pipelines, and time-series data, ideally within automotive or sensor-heavy environments.</p><p><strong>What You’ll Do</strong></p><ul><li>Build and optimize data pipelines for large-scale vehicle and sensor data</li><li>Deploy scalable ML workflows using AWS, PySpark, and Terraform</li><li>Support data scientists with clean, structured, and accessible datasets</li><li>Develop dashboards and reporting tools (QuickSight, Power BI)</li></ul><p><strong>Your Background</strong></p><ul><li>Master’s in Data Science or similar</li><li>Skilled in Python, AWS, PySpark, Terraform, and signal processing</li><li>Experience with vehicle data, cloud infrastructure, or ML pipelines</li><li>Strong analytical and problem-solving mindset</li></ul><p><br></p><p><strong>Please send Your CV to jobs@telescopeservices.se.</strong></p>",
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5568072820',
#     'name': 'Nexer Telescope AB',
#     'workplace': 'Telescope Services AB'},
#    'application_details': {'information': None,
#     'reference': 'TSS-DAE-210825',
#     'email': 'jobs@telescopeservices.se',
#     'via_af': False,
#     'url': None,
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'fciS_GRw_wk5',
#     'label': 'Dataoperatör',
#     'legacy_ams_taxonomy_id': '6027'},
#    'occupation_group': {'concept_id': '13md_uyV_BNG',
#     'label': 'Drifttekniker, IT',
#     'legacy_ams_taxonomy_id': '3511'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Lund',
#     'municipality_code': '1281',
#     'municipality_concept_id': 'muSY_tsR_vDZ',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': 'Scheelevägen 16',
#     'postcode': '22363',
#     'city': 'Lund',
#     'coordinates': [13.2194708109225, 55.7150970449687]},
#    'must_have': {'skills': [],
#     'languages': [{'weight': 10,
#       'concept_id': 'NVxJ_hLg_TYS',
#       'label': 'Engelska',
#       'legacy_ams_taxonomy_id': '283'}],
#     'work_experiences': [{'weight': 10,
#       'concept_id': 'fciS_GRw_wk5',
#       'label': 'Dataoperatör',
#       'legacy_ams_taxonomy_id': '6027'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-08-21T17:08:15',
#    'last_publication_date': '2025-11-19T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1755788895662},
#   {'relevance': 1.0,
#    'id': '29932692',
#    'external_id': '46-556267-5164-300752-183861',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29932692',
#    'logo_url': None,
#    'headline': 'Data Engineer',
#    'application_deadline': '2025-09-26T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Are you ready to be at the forefront of digital innovation? Join our dynamic team at Tele2, where Digital Capabilities & Technology (DCT) is the engine behind our products and services. As the essential enabler of our commercial\nambitions, DCT brings automation and simplicity to the telecommunications industry, revolutionizing the way we connect and communicate.\nWithin our organization, you’ll find everything from the backbone infrastructure of technology and IT systems, serving both our external & internal customers, to advanced analytics, AI creation, and frontend development. Our team plays a vital role in ensuring reliable and premium services through delivering exceptional experiences to our end customers, both Consumer and Enterprises, all the while supporting our colleagues within Tele2.\n\nABOUT THE ROLE \n\nWe are looking for a Data Pipeline Expert with a track record of +4 years building ingestion and transformation frameworks that can handle large, fast-growing datasets with ease on AWS and Redshift, to join our B2B Data & Analytical team within IT B2B Billing and Data Services. The team is today responsible for the development in larger technology programs and projects supporting our B2B customer needs.\n\nAs a Data Engineer, you will be responsible for developing, maintaining, and optimizing our data pipelines and data products. You will work closely with data scientists, analysts, and other engineers to deliver high-quality, reliable, and efficient data solutions that power business intelligence and analytics initiatives. To succeed in this role, you have a passion for agility, maintain a positive attitude and have the ability to create strong team spirit and relationships across functional teams.\n\nKEY RESPONSIBILITIES\n\n·Design, develop, and maintain scalable and efficient data pipelines to extract, transform, and load (ETL) data using Snowflake, Redshift, dbt, Apache Airflow and other cloud-based technologies.\n\n·Collaborate with data scientists, analysts, and business stakeholders to understand data needs and design appropriate solutions.\n\n·Build and maintain data models, ensuring data is accurate, consistent, and easily accessible for analytics and reporting.\n\n·Implement modern data transformation tools and frameworks (e.g., dbt, Apache Airflow) to streamline data processing workflows.\n\n·Monitor and troubleshoot data pipeline issues, ensuring high reliability and data quality.\r\nQUALIFICATIONS\n\n·Minimum 4 years of experience in data engineering with a strong focus on modern cloud-based data technologies\n\n·Proficiency in SQL, and experience with data modeling, ETL processes, and data integration\n\n·Hands-on experience with Redshift, including database design, data ingestion, performance optimization, and security. Snowflake is a plus.\n\n·Familiarity with data transformation tools like dbt, Apache Airflow, Talend, or similar tools\n\n·Experience working with AWS cloud platform and its associated data services (e.g., S3, Lambda, Glue, Redshift)\n\n·Experience with version control (Git), Docker, Kubernetes, CI/CD, and infrastructure-as-code tools (Terraform)\n\n·Knowledge of Python, Java, or other programming languages for data engineering tasks is a plus\n\n·Excellent problem-solving and communication skills, with the ability to work collaboratively across teams\n\n·Telecom and B2B industry background is an extra plus \n\n·Proficient in English, oral and written\n\n\n\nWhy Tele2\n\n\n - \nWe believe in fostering a creative and flexible work environment. You will be part of a culture where teamwork and inclusion are leading the way forward, a place where you bring your whole self to work as the unique person you are. We are committed to building a company that values diversity in all its forms.\n\n\n - \nEvery employee is important for the company’s success and you will always have an impact through your work with opportunities for growth and development through inte ...
#     'text_formatted': 'Are you ready to be at the forefront of digital innovation? Join our dynamic team at Tele2, where Digital Capabilities &amp; Technology (DCT) is the engine behind our products and services. As the essential enabler of our commercial\nambitions, DCT brings automation and simplicity to the telecommunications industry, revolutionizing the way we connect and communicate.\nWithin our organization, you’ll find everything from the backbone infrastructure of technology and IT systems, serving both our external &amp; internal customers, to advanced analytics, AI creation, and frontend development. Our team plays a vital role in ensuring reliable and premium services through delivering exceptional experiences to our end customers, both Consumer and Enterprises, all the while supporting our colleagues within Tele2.\n\nABOUT THE ROLE \n\nWe are looking for a Data Pipeline Expert with a track record of +4 years building ingestion and transformation frameworks that can handle large, fast-growing datasets with ease on AWS and Redshift, to join our B2B Data &amp; Analytical team within IT B2B Billing and Data Services. The team is today responsible for the development in larger technology programs and projects supporting our B2B customer needs.\n\nAs a Data Engineer, you will be responsible for developing, maintaining, and optimizing our data pipelines and data products. You will work closely with data scientists, analysts, and other engineers to deliver high-quality, reliable, and efficient data solutions that power business intelligence and analytics initiatives. To succeed in this role, you have a passion for agility, maintain a positive attitude and have the ability to create strong team spirit and relationships across functional teams.\n\nKEY RESPONSIBILITIES\n\n·Design, develop, and maintain scalable and efficient data pipelines to extract, transform, and load (ETL) data using Snowflake, Redshift, dbt, Apache Airflow and other cloud-based technologies.\n\n·Collaborate with data scientists, analysts, and business stakeholders to understand data needs and design appropriate solutions.\n\n·Build and maintain data models, ensuring data is accurate, consistent, and easily accessible for analytics and reporting.\n\n·Implement modern data transformation tools and frameworks (e.g., dbt, Apache Airflow) to streamline data processing workflows.\n\n·Monitor and troubleshoot data pipeline issues, ensuring high reliability and data quality.\r\nQUALIFICATIONS\n\n·Minimum 4 years of experience in data engineering with a strong focus on modern cloud-based data technologies\n\n·Proficiency in SQL, and experience with data modeling, ETL processes, and data integration\n\n·Hands-on experience with Redshift, including database design, data ingestion, performance optimization, and security. Snowflake is a plus.\n\n·Familiarity with data transformation tools like dbt, Apache Airflow, Talend, or similar tools\n\n·Experience working with AWS cloud platform and its associated data services (e.g., S3, Lambda, Glue, Redshift)\n\n·Experience with version control (Git), Docker, Kubernetes, CI/CD, and infrastructure-as-code tools (Terraform)\n\n·Knowledge of Python, Java, or other programming languages for data engineering tasks is a plus\n\n·Excellent problem-solving and communication skills, with the ability to work collaboratively across teams\n\n·Telecom and B2B industry background is an extra plus \n\n·Proficient in English, oral and written\n\n\n\nWhy Tele2\n\n\n - \nWe believe in fostering a creative and flexible work environment. You will be part of a culture where teamwork and inclusion are leading the way forward, a place where you bring your whole self to work as the unique person you are. We are committed to building a company that values diversity in all its forms.\n\n\n - \nEvery employee is important for the company’s success and you will always have an impact through your work with opportunities for growth and development throu ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid\r\nTillsvidare'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Fast månads- vecko- eller timlön',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': 'https://www.tele2.com/',
#     'organization_number': '5562675164',
#     'name': 'Tele2 Sverige AB',
#     'workplace': 'Tele2 Sweden AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': None,
#     'via_af': False,
#     'url': 'https://emp.jobylon.com/applications/jobs/300752/create/?utm_source=ams&utm_medium=promotionserializer',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_address': {'municipality': None,
#     'municipality_code': None,
#     'municipality_concept_id': None,
#     'region': None,
#     'region_code': None,
#     'region_concept_id': None,
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [None, None]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': '9U5Y_9Ji_uJq',
#       'label': 'Dataingenjör',
#       'legacy_ams_taxonomy_id': '7338'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [],
#    'publication_date': '2025-08-21T10:17:15',
#    'last_publication_date': '2025-09-26T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1755764235746},
#   {'relevance': 1.0,
#    'id': '29916059',
#    'external_id': None,
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29916059',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/arbetsplatser/88288273/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2025-08-31T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'Role: Data Engineer (Nearshore)\nResponsibilities:\nTake full ownership of designing, optimizing, and supporting both existing and new data products in line with the target vision.\nPromote and apply DevOps principles, managing CI/CD pipelines, Terraform, and cloud infrastructure, primarily within Google Cloud Platform (GCP).\nEnsure data products function as independent deployable units, meeting established standards for security, scalability, observability, and performance.\nCollaborate closely with the Product Owner and other stakeholders to refine the vision for current solutions and identify opportunities for new data products that address customer needs.\nCooperate with internal and external product teams on initiatives connected to the data mesh approach.\nDrive continuous improvement, reduce technical debt, and encourage best practices within the team.\nStay up to date with advancements in data, analytics, and cloud technologies.\n\nQualifications:\nStrong passion for data, technology, and collaboration.\nMinimum of 4 years of professional experience, ideally as a Data Engineer working with modern cloud data platforms or advanced analytics, or as a Software Engineer focusing on cloud technologies and infrastructure.\nHands-on experience with multiple data formats (e.g., Avro, Parquet).\nProficiency in SQL or other query languages.\nProgramming expertise in Python, Java, and/or Scala for data-focused development.\nSolid understanding of data modeling techniques and their trade-offs.\nKnowledge of both NoSQL and relational database systems.\nExcellent communication skills with a collaborative and proactive mindset.\nComfortable making decisions independently and working in a self-directed environment.\nExperience with data visualization tools is an advantage.\nFluent in English, both spoken and written.\n\n\n\nAbout Rasulson Consulting\nRasulson Consulting is a specialized staffing and recruitment firm focused on the IT sector. We collaborate with leading tech companies and innovative startups to provide exciting career opportunities for individuals passionate about digital development. With our deep technical expertise and extensive network, we efficiently match the right talents with the right assignments. At Rasulson Consulting, you’ll receive personalized guidance, regular feedback, and the chance to take the next step in your IT career.',
#     'text_formatted': '<p>Role: Data Engineer (Nearshore)</p><p>Responsibilities:</p><ul><li>Take full ownership of designing, optimizing, and supporting both existing and new data products in line with the target vision.</li><li>Promote and apply DevOps principles, managing CI/CD pipelines, Terraform, and cloud infrastructure, primarily within Google Cloud Platform (GCP).</li><li>Ensure data products function as independent deployable units, meeting established standards for security, scalability, observability, and performance.</li><li>Collaborate closely with the Product Owner and other stakeholders to refine the vision for current solutions and identify opportunities for new data products that address customer needs.</li><li>Cooperate with internal and external product teams on initiatives connected to the data mesh approach.</li><li>Drive continuous improvement, reduce technical debt, and encourage best practices within the team.</li><li>Stay up to date with advancements in data, analytics, and cloud technologies.</li></ul><p>Qualifications:</p><ul><li>Strong passion for data, technology, and collaboration.</li><li>Minimum of 4 years of professional experience, ideally as a Data Engineer working with modern cloud data platforms or advanced analytics, or as a Software Engineer focusing on cloud technologies and infrastructure.</li><li>Hands-on experience with multiple data formats (e.g., Avro, Parquet).</li><li>Proficiency in SQL or other query languages.</li><li>Programming expertise in Python, Java, and/or Scala for data-focused development.</li><li>Solid understanding of data modeling techniques and their trade-offs.</li><li>Knowledge of both NoSQL and relational database systems.</li><li>Excellent communication skills with a collaborative and proactive mindset.</li><li>Comfortable making decisions independently and working in a self-directed environment.</li><li>Experience with data visualization tools is an advantage.</li><li>Fluent in English, both spoken and written.</li></ul><p><br></p><p><strong>About Rasulson Consulting</strong></p><p>Rasulson Consulting is a specialized staffing and recruitment firm focused on the IT sector. We collaborate with leading tech companies and innovative startups to provide exciting career opportunities for individuals passionate about digital development. With our deep technical expertise and extensive network, we efficiently match the right talents with the right assignments. At Rasulson Consulting, you’ll receive personalized guidance, regular feedback, and the chance to take the next step in your IT career.</p><p><br></p>',
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': None},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': None,
#    'duration': {'concept_id': 'qQUd_4qe_NDT',
#     'label': '6 månader eller längre',
#     'legacy_ams_taxonomy_id': '2'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5593220733',
#     'name': 'Rasulson Consulting AB',
#     'workplace': 'Rasulson Consulting AB'},
#    'application_details': {'information': None,
#     'reference': None,
#     'email': 'yahyo.said@rasulson.com',
#     'via_af': False,
#     'url': 'https://jobb.rasulson.com/jobs/6312514-data-engineer',
#     'other': None},
#    'experience_required': True,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': '9U5Y_9Ji_uJq',
#     'label': 'Dataingenjör',
#     'legacy_ams_taxonomy_id': '7338'},
#    'occupation_group': {'concept_id': 'nDaB_vdy_eAy',
#     'label': 'Ingenjörer och tekniker inom elektroteknik',
#     'legacy_ams_taxonomy_id': '3113'},
#    'occupation_field': {'concept_id': '6Hq3_tKo_V57',
#     'label': 'Yrken med teknisk inriktning',
#     'legacy_ams_taxonomy_id': '18'},
#    'workplace_address': {'municipality': 'Stockholm',
#     'municipality_code': '0180',
#     'municipality_concept_id': 'AvNB_uwa_6n6',
#     'region': 'Stockholms län',
#     'region_code': '01',
#     'region_concept_id': 'CifL_Rzy_Mku',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': '11818',
#     'city': 'STOCKHOLM',
#     'coordinates': [18.056118347108487, 59.31664285205177]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [{'weight': 10,
#       'concept_id': '9U5Y_9Ji_uJq',
#       'label': 'Dataingenjör',
#       'legacy_ams_taxonomy_id': '7338'}],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': 'Yahyo Said',
#      'description': None,
#      'email': 'yahyo.said@rasulson.com',
#      'telephone': '0142-150 00',
#      'contact_type': None}],
#    'publication_date': '2025-08-17T19:09:50',
#    'last_publication_date': '2025-08-31T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_ANNONSERA',
#    'timestamp': 1755450590670},
#   {'relevance': 1.0,
#    'id': '29913080',
#    'external_id': '46-556391-0354-6310373-1',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29913080',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/5563910354/logotyper/logo.png',
#    'headline': 'Data Engineer',
#    'application_deadline': '2026-02-01T23:59:59',
#    'number_of_vacancies': 1,
# ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid\r\nPermanent'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Not Specified',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5562536143',
#     'name': 'Axis Communications AB',
#     'workplace': 'Axis Communications'},
#    'application_details': {'information': None,
#     'reference': 'R-122286',
#     'email': None,
#     'via_af': False,
#     'url': 'https://www.aplitrak.com/?adid=cmViZWNjYS5tYXNzZWNrLjY1MTcyLjMxMDFAYXhpc2NvbW1zLmFwbGl0cmFrLmNvbQ',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'rQds_YGd_quU',
#     'label': 'Mjukvaruutvecklare',
#     'legacy_ams_taxonomy_id': '80'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Lund',
#     'municipality_code': '1281',
#     'municipality_concept_id': 'muSY_tsR_vDZ',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [13.191008, 55.70466]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Axis Communications AB',
#      'email': None,
#      'telephone': None,
#      'contact_type': None}],
#    'publication_date': '2025-08-05T09:43:28',
#    'last_publication_date': '2025-09-02T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1754379808071},
#   {'relevance': 0.25727640950669506,
#    'id': '29878537',
#    'external_id': '46-556253-6143-R-122288',
#    'original_id': None,
#    'label': '[]',
#    'webpage_url': 'https://arbetsformedlingen.se/platsbanken/annonser/29878537',
#    'logo_url': 'https://arbetsformedlingen.se/rest/agas/api/v1/organisation/5562536143/logotyper/logo.png',
#    'headline': 'Senior Software Engineer - Data & Video Analytics, Lund',
#    'application_deadline': '2025-09-02T23:59:59',
#    'number_of_vacancies': 1,
#    'description': {'text': 'In the open office landscape, you look around the room and see others who share your passion. Emersed in focused coding or in a soft tuned dialogue you are a team of innovators, working together to create a smarter, safer world. Your teammate meets your eye with a smile and you decide to go for a freshly brewed coffee. Returning to your desks feeling refreshed and focused you dive back into problem solving with renewed vigor and a shared enthusiasm. Ideas flows freely, and the collective energy is palpable. Welcome to Axis Analytics solutions - a place where passion met purpose, and every day presents an opportunity to make a positive impact.\n\nYour future team\nInside Axis Analytics Solutions, we\'re a team of engineers who collaborate seamlessly for data-driven development and evaluation of our analytics solutions. Our scope includes data curation, algorithm development and evaluation as well as a toolchain to support our everyday activities.\n\nOne of Axis greatest assets is our culture with a strong focus on collaboration. We know that good ideas can come anytime and anywhere and therefore we encourage everyone to contribute and be innovative. If you are a person who likes to make a difference, you will feel right at home with us! As a member of our team, you\'ll enjoy a culture that encourages collaboration, learning, and growth. We want you to enjoy working with us and we believe team spirit, equal opportunities for all and having fun are central parts in this.\n\nYour Role: A Hands-On Software Architect\nTo complement our existing strengths, we are looking for you to join our crew and bring your own unique approach and experiences all the while respecting Axis core values - Act as one, Always open, Think big. As a senior software engineer, you\'ll be instrumental in designing and implementing full-stack scalable solutions, from concept to delivery. Together we will tackle complex system issues, and your expertise in design patterns, software product architecture, and Kubernetes will be invaluable. In our team you will not only be an exceptional coder but also a mentor and leader who can inspire and grow our team. We want you to contribute across our scope and be happy to chip in where you are needed the most. Whether it is to enhance our tools for evaluation, visualization and annotation or our algorithm product solutions.\n\nWho are you?\nAlthough we do not know you yet, we believe you are a person who is trustworthy and respected in your professional role. We expect you thrive when collaborating with your team and are experienced, pragmatic and proactive in suggesting solutions to the technical challenges we are tackling. We hope you are curious and passionate in the production of high quality, robust and reusable code and someone who has built software products from design to validation. Continuous improvement is important to you and it\'s natural for you to share your knowledge so that we learn alongside you and you with us.\n\nMore concretely, we would like you to bring:\n\n * Excellence in Python and perhaps some C++ on Linux platforms\n * Strong professionalism in design patterns and clean coding\n * Practical knowledge of SW system design and architecture\n * Familiarity with Docker, Kubernetes and Git\n * Understanding of database and event systems\n * Excellent collaboration and communication with fluency in English and Swedish is a bonus\n\nIt would also be nice if you have some:\n\n * Frontend development experience with React\n * Knowledge of cameras, web, and cloud technologies\n * Experience in computer vision and video analytics software and some insights into Artificial Intelligence libraries\n\nWhat Axis has to offer\nWe are a world leader in network video, where cutting-edge technology meets global impact. Here, you\'ll contribute to meaningful projects that shape the future of security and surveillance - developing solutions used worldwide. As a fast-growing company, we o ...
#     'text_formatted': 'In the open office landscape, you look around the room and see others who share your passion. Emersed in focused coding or in a soft tuned dialogue you are a team of innovators, working together to create a smarter, safer world. Your teammate meets your eye with a smile and you decide to go for a freshly brewed coffee. Returning to your desks feeling refreshed and focused you dive back into problem solving with renewed vigor and a shared enthusiasm. Ideas flows freely, and the collective energy is palpable. Welcome to Axis Analytics solutions - a place where passion met purpose, and every day presents an opportunity to make a positive impact.\n\nYour future team\nInside Axis Analytics Solutions, we\'re a team of engineers who collaborate seamlessly for data-driven development and evaluation of our analytics solutions. Our scope includes data curation, algorithm development and evaluation as well as a toolchain to support our everyday activities.\n\nOne of Axis greatest assets is our culture with a strong focus on collaboration. We know that good ideas can come anytime and anywhere and therefore we encourage everyone to contribute and be innovative. If you are a person who likes to make a difference, you will feel right at home with us! As a member of our team, you\'ll enjoy a culture that encourages collaboration, learning, and growth. We want you to enjoy working with us and we believe team spirit, equal opportunities for all and having fun are central parts in this.\n\nYour Role: A Hands-On Software Architect\nTo complement our existing strengths, we are looking for you to join our crew and bring your own unique approach and experiences all the while respecting Axis core values - Act as one, Always open, Think big. As a senior software engineer, you\'ll be instrumental in designing and implementing full-stack scalable solutions, from concept to delivery. Together we will tackle complex system issues, and your expertise in design patterns, software product architecture, and Kubernetes will be invaluable. In our team you will not only be an exceptional coder but also a mentor and leader who can inspire and grow our team. We want you to contribute across our scope and be happy to chip in where you are needed the most. Whether it is to enhance our tools for evaluation, visualization and annotation or our algorithm product solutions.\n\nWho are you?\nAlthough we do not know you yet, we believe you are a person who is trustworthy and respected in your professional role. We expect you thrive when collaborating with your team and are experienced, pragmatic and proactive in suggesting solutions to the technical challenges we are tackling. We hope you are curious and passionate in the production of high quality, robust and reusable code and someone who has built software products from design to validation. Continuous improvement is important to you and it\'s natural for you to share your knowledge so that we learn alongside you and you with us.\n\nMore concretely, we would like you to bring:\n\n * Excellence in Python and perhaps some C++ on Linux platforms\n * Strong professionalism in design patterns and clean coding\n * Practical knowledge of SW system design and architecture\n * Familiarity with Docker, Kubernetes and Git\n * Understanding of database and event systems\n * Excellent collaboration and communication with fluency in English and Swedish is a bonus\n\nIt would also be nice if you have some:\n\n * Frontend development experience with React\n * Knowledge of cameras, web, and cloud technologies\n * Experience in computer vision and video analytics software and some insights into Artificial Intelligence libraries\n\nWhat Axis has to offer\nWe are a world leader in network video, where cutting-edge technology meets global impact. Here, you\'ll contribute to meaningful projects that shape the future of security and surveillance - developing solutions used worldwide. As a fast-growing company, we offer  ...
#     'company_information': None,
#     'needs': None,
#     'requirements': None,
#     'conditions': 'Heltid\r\nPermanent'},
#    'employment_type': {'concept_id': 'PFZr_Syz_cUq',
#     'label': 'Vanlig anställning',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_type': {'concept_id': 'oG8G_9cW_nRf',
#     'label': 'Fast månads- vecko- eller timlön',
#     'legacy_ams_taxonomy_id': '1'},
#    'salary_description': 'Not Specified',
#    'duration': {'concept_id': 'a7uU_j21_mkL',
#     'label': 'Tills vidare',
#     'legacy_ams_taxonomy_id': '1'},
#    'working_hours_type': {'concept_id': '6YE1_gAC_R2G',
#     'label': 'Heltid',
#     'legacy_ams_taxonomy_id': '1'},
#    'scope_of_work': {'min': 100, 'max': 100},
#    'access': None,
#    'employer': {'phone_number': None,
#     'email': None,
#     'url': None,
#     'organization_number': '5562536143',
#     'name': 'Axis Communications AB',
#     'workplace': 'Axis Communications'},
#    'application_details': {'information': None,
#     'reference': 'R-122288',
#     'email': None,
#     'via_af': False,
#     'url': 'https://www.aplitrak.com/?adid=cmViZWNjYS5tYXNzZWNrLjg2NTk2LjMxMDFAYXhpc2NvbW1zLmFwbGl0cmFrLmNvbQ',
#     'other': None},
#    'experience_required': False,
#    'access_to_own_car': False,
#    'driving_license_required': False,
#    'driving_license': None,
#    'occupation': {'concept_id': 'rQds_YGd_quU',
#     'label': 'Mjukvaruutvecklare',
#     'legacy_ams_taxonomy_id': '80'},
#    'occupation_group': {'concept_id': 'DJh5_yyF_hEM',
#     'label': 'Mjukvaru- och systemutvecklare m.fl.',
#     'legacy_ams_taxonomy_id': '2512'},
#    'occupation_field': {'concept_id': 'apaJ_2ja_LuF',
#     'label': 'Data/IT',
#     'legacy_ams_taxonomy_id': '3'},
#    'workplace_address': {'municipality': 'Lund',
#     'municipality_code': '1281',
#     'municipality_concept_id': 'muSY_tsR_vDZ',
#     'region': 'Skåne län',
#     'region_code': '12',
#     'region_concept_id': 'CaRE_1nn_cSU',
#     'country': 'Sverige',
#     'country_code': '199',
#     'country_concept_id': 'i46j_HmG_v64',
#     'street_address': None,
#     'postcode': None,
#     'city': None,
#     'coordinates': [13.191008, 55.70466]},
#    'must_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'nice_to_have': {'skills': [],
#     'languages': [],
#     'work_experiences': [],
#     'education': [],
#     'education_level': []},
#    'application_contacts': [{'name': None,
#      'description': 'Axis Communications AB',
#      'email': None,
#      'telephone': None,
#      'contact_type': None}],
#    'publication_date': '2025-08-05T09:39:37',
#    'last_publication_date': '2025-09-02T23:59:59',
#    'removed': False,
#    'removed_date': None,
#    'source_type': 'VIA_PLATSBANKEN_DXA',
#    'timestamp': 1754379577532}]}

# %%
json_response["hits"][-1]["headline"], json_response["hits"][-1]["employer"]["name"]
# Out:
# ('Senior Software Engineer - Data & Video Analytics, Lund',
#  'Axis Communications AB')
